# %% [markdown]
# # Chapter 03 리스트와 집합
# ## 학습목표
# * 리스트의 개념 및 추상 자료형 이해
# * 배열 구조와 연결된 구조의 차이를 정확히 이해
# * 파이썬 리스트 내부 동작 원리 이해
# * 자료구조 리스트를 파이썬 리스트로 구현하는 방법 이해
# * 자료구조를 함수와 클래스로 구현하는방법의 차이를 이해
# * 집합의 개념과 구현 방법 이해
# * 자료구조의 각 연산들에 대한 시간 복잡도 분석 능력 기르기

# %% [markdown]
# ## 3.1 리스트란?
# * 항목들이 순서대로 나열되어 있고, 각 항목들은 위치를 가짐
# * Stack, Queue, Deque와는 자료의 접근 위치에서 다름

# %% [markdown]
# ### List ADT
#     데이터 : 같은 유형의 요소들의 순서 있는 모임
#     연산
#     * insert(pos, e)
#     * delete(pos)
#     * isEmpty()
#     * getEntry(pos)
#     etc...

# %% [markdown]
# ### 리스트 구현 방법
# * 배열 구조
#     * 구현이 간단
#     * 항목 접근이 O(1)
#     * 삽입, 삭제시 오버헤드
#     * 항목의 개수 제한
#
# * 연결된 구조
#     * 구현이 복잡
#     * 항목 접근이 O(n)
#     * 삽입, 삭제가 효율적
#     * 크기가 제한되지 않음

# %% [markdown]
# ### 리스트 용어 정리
# * 파이썬 리스트 : 배열 또는 배열구조의 의미
# * 연결 리스트 : 자료들이 일렬로 나열할 수 있는 연결된 구조. 배열 구조에 대응되는 의미
# * 자료구조 리스트 :

# %% [markdown]
# ## 3.2 파이썬 리스트

# %% [markdown]
# ## 3.3 배열로 구현한 리스트

# %% [markdown]
# 함수 ver

# %%
items = []

def insert(pos, elem):
    items.insert(pos, elem)
def

# %% [markdown]
# ## 3.4

# %%
class ArrayList:		  
    def __init__( self ):
        self.items = []		

    def insert(self, pos, elem) :
        self.items.insert(pos, elem)
    def delete(self, pos) :
        self.items.pop(pos)
    def isEmpty( self ):
        return self.size() == 0
    def getEntry(self, pos) :
        return self.items[pos]
    def size( self ):
        return len(self.items)
    def clear( self ) :
        self.items = []	
    def find(self, item) :
        return self.items.index(item)
    def replace(self, pos, elem) :
        self.items[pos] = elem
    def sort(self) :
        self.items.sort()
    def merge(self, lst) :
        self.items.extend(lst)
    def display(self, msg='ArrayList:' ):
        print(msg, self.size(), self.items)


def myLineEditor() :	
    list = ArrayList()	
    while True :
        command = input("[메뉴선택] i-입력, d-삭제, r-변경, p-출력, l-파일읽기, s-저장, q-종료=> ")
        if command == 'i' :		
            pos = int( input("  입력행 번호: "))
            str = input("  입력행 내용: ")	    
            list.insert(pos, str)		
        elif command == 'd' :			
            pos = int( input("  삭제행 번호: "))
            list.delete(pos)			
        elif command == 'r' :			
            pos = int( input("  변경행 번호: "))
            str = input("  변경행 내용: ")	    
            list.replace(pos, str)		        
        elif command == 'q' : return	        
        elif command == 'p' :		            
            print('Line Editor')
            for line in range (list.size()) :   
                print('[%2d] '%line, end='')    
                print(list.getEntry(line))      
            print()			                    
        elif command == 'l' :			        
            filename = 'test.txt'
            infile = open(filename , "r")       
            lines = infile.readlines()	        
            for line in lines:		            
                list.insert(list.size(), line.rstrip('\n'))
            infile.close()			
        elif command == 's' :		
            filename = 'test.txt'
            outfile = open(filename , "w")
            for i in range(list.size()) :
                outfile.write(list.getItem(i)+'\n')
            outfile.close()

myLineEditor()
# Out:
# [메뉴선택] i-입력, d-삭제, r-변경, p-출력, l-파일읽기, s-저장, q-종료=> l
# [메뉴선택] i-입력, d-삭제, r-변경, p-출력, l-파일읽기, s-저장, q-종료=> p
# Line Editor
# [ 0] Hello, my name is kim
# [ 1] ok???
# [ 2] good night!
#
# [메뉴선택] i-입력, d-삭제, r-변경, p-출력, l-파일읽기, s-저장, q-종료=> q
